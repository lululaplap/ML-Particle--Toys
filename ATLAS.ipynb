# %% [markdown]
# Import data

# %%
import subprocess
print(subprocess.call(["wget","-O","diboson.csv","https://cernbox.cern.ch/index.php/s/tdZ3O7jf8xuBf10/download?path=%2F&x-access-token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..dp8ZZnExlcrAiRRlTs8Ztph6Vxk2PESc7XYD3JGU8-I&files=Diboson.csv"]))
print(subprocess.call(["wget","-O","ggH.csv","https://cernbox.cern.ch/index.php/s/tdZ3O7jf8xuBf10/download?path=%2F&x-access-token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..1l23zZKcTr0besYSP-8pINNwLnkcHI6oAE3hn7jfwZg&files=ggH1000.csv"]))
print(subprocess.call(["wget","-O","top.csv","https://cernbox.cern.ch/index.php/s/tdZ3O7jf8xuBf10/download?path=%2F&x-access-token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..1l23zZKcTr0besYSP-8pINNwLnkcHI6oAE3hn7jfwZg&files=Top.csv"]))
print(subprocess.call(["wget","-O","Zjets.csv","https://cernbox.cern.ch/index.php/s/tdZ3O7jf8xuBf10/download?path=%2F&x-access-token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..1l23zZKcTr0besYSP-8pINNwLnkcHI6oAE3hn7jfwZg&files=Zjets.csv"]))
# Out:
# 0
# 0
# 0
# 0

# %%
import pandas as pd
frames = [_,_,_,_,]
frames[1] = pd.read_csv("diboson.csv")
frames[0] = pd.read_csv("ggH.csv")
frames[2] = pd.read_csv("top.csv")
frames[3] = pd.read_csv("Zjets.csv")

# %% [markdown]
# check for nans and everything is the same size

# %%
import numpy as np
for frame in frames:
    #check if NaNs
    print(np.sum(np.isfinite(frame)))
    #check data sizes
    print(frame.shape)
# Out:
# Unnamed: 0         50013
# FullEventWeight    50013
# MET                50013
# Topology           50013
# Zll_mass           50013
# Zll_pt             50013
# fatjet_C2          50013
# fatjet_D2          50013
# fatjet_E           50013
# fatjet_eta         50013
# fatjet_phi         50013
# fatjet_pt          50013
# isSignal           50013
# lep1_E             50013
# lep1_charge        50013
# lep1_eta           50013
# lep1_phi           50013
# lep1_pt            50013
# lep2_E             50013
# lep2_charge        50013
# lep2_eta           50013
# lep2_phi           50013
# lep2_pt            50013
# reco_zv_mass       50013
# truth_zv_mass      50013
# dtype: int64
# (50013, 25)
# Unnamed: 0         155127
# FullEventWeight    155127
# MET                155127
# Topology           155127
# Zll_mass           155127
# Zll_pt             155127
# fatjet_C2          155127
# fatjet_D2          155127
# fatjet_E           155127
# fatjet_eta         155127
# ...

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import seaborn as sn

# %%
frames[0].head()
# Out:
#    Unnamed: 0  FullEventWeight        MET  Topology  Zll_mass     Zll_pt  \
# 0           0         0.013603  44495.770         1  87475.55  627990.80
# 1           1         0.242178  34441.156         1  90507.31  409780.94
# 2           2         0.096412  21625.379         0  89765.85  344668.30
# 3           3         0.096373  21855.973         1  92313.63  535629.06
# 4           4         0.073052  33677.380         1  89451.92  296257.47
#
#    fatjet_C2  fatjet_D2   fatjet_E  fatjet_eta  ...  lep1_eta  lep1_phi  \
# 0   0.116438   0.889354  675246.25   -0.851387  ... -0.906080 -1.876361
# 1   0.191874   1.485706  604275.70    1.041311  ...  2.363212  2.032987
# 2   0.122089   1.219367  612517.94    0.417858  ...  1.217849  0.664946
# 3   0.061306   0.592705  482630.90    0.438590  ... -0.045790 -0.626280
# 4   0.159334   0.724910  459737.80    1.213717  ... -1.289961  2.238501
#
#      lep1_pt      lep2_E  lep2_charge  lep2_eta  lep2_phi    lep2_pt  \
# ...

# %%
frames[1].head()
# Out:
#    Unnamed: 0  FullEventWeight         MET  Topology    Zll_mass      Zll_pt  \
# 0           0         0.387345   41920.540         0  187549.810  374316.600
# 1           1         0.172328  225618.530         0   13106.807   51429.535
# 2           2         0.371392   42284.125         0   84519.230  153790.270
# 3           3         0.309902   42735.938         1   76138.640  102611.836
# 4           4         0.202772   70475.780         0   86138.000  141886.280
#
#    fatjet_C2  fatjet_D2   fatjet_E  fatjet_eta  ...  lep1_eta  lep1_phi  \
# 0   0.127114   1.786927  353161.47   -0.001591  ...  1.677279 -1.346853
# 1   0.269517   2.296220  357617.66   -1.066937  ... -2.057147  2.975854
# 2   0.051175   3.360730  345472.30    0.704825  ... -0.285897 -0.084159
# 3   0.117028   0.702838  476446.80    0.095546  ... -0.160614 -2.544057
# 4   0.053951   3.634348  799487.75   -1.828396  ... -0.499056  0.429884
#
# ...

# %%
frames[2].head()
# Out:
#    Unnamed: 0  FullEventWeight         MET  Topology    Zll_mass      Zll_pt  \
# 0           0     2.004522e-09   51609.760         1   35253.492   35612.324
# 1           1     1.822626e-09  225038.800         1   20311.205   38644.793
# 2           2     1.552981e-09   27090.697         1  134715.500  244261.840
# 3           3     1.660535e-09   57572.890         0   69086.836   90045.625
# 4           4     1.461494e-09  123177.900         0   51731.508   52780.684
#
#    fatjet_C2  fatjet_D2   fatjet_E  fatjet_eta  ...  lep1_eta  lep1_phi  \
# 0   0.109581   1.435712  461309.30   -1.195378  ...  0.164823  1.042926
# 1   0.090346   2.403266  276659.70    0.387434  ... -1.871251  0.601309
# 2   0.212569   1.336584  900965.50   -1.822714  ...  0.701193  2.446600
# 3   0.133918   1.780693  596016.20   -1.725750  ... -2.305750  0.627527
# 4   0.101556   3.398984  590811.44    1.477704  ... -0.685020 -2.360906
#
# ...

# %%
frames[3].head()
# Out:
#    Unnamed: 0  FullEventWeight         MET  Topology   Zll_mass     Zll_pt  \
# 0           0        -0.790471  177227.420         1  95697.766  64252.690
# 1           1         0.789204   10660.757         1  90289.914  32506.705
# 2           2        -0.872639  655334.400         1  92994.430  55287.625
# 3           3        -0.772697   41489.973         1  89607.580  63405.484
# 4           4         1.581337   41731.630         1  90199.480  47187.332
#
#    fatjet_C2  fatjet_D2   fatjet_E  fatjet_eta  ...  lep1_eta  lep1_phi  \
# 0   0.097862   1.895164  425871.88   -1.329446  ...  1.782276 -1.057460
# 1   0.000000   0.000000  247948.36   -0.429050  ... -0.918399 -1.229385
# 2   0.059006   2.463149  630492.94   -0.543789  ... -1.091297  0.865696
# 3   0.265080   2.081222  610611.56    1.776149  ...  1.238367  2.127853
# 4   0.093765   2.321676  781746.90   -1.524169  ... -0.116431  1.745413
#
#      lep1_pt     lep2_E  lep2_charge  lep2_eta  lep2_phi    lep2_pt  \
# ...

# %% [markdown]
# Plot the feature distributiuons

# %%
features = ["lep2_pt","lep1_pt","fatjet_pt","fatjet_eta","fatjet_D2","Zll_mass","Zll_pt","MET","reco_zv_mass","isSignal"]

# %%
import matplotlib.pyplot as plt
for f in features[:-1]:
    for frame in frames:
        frame["lep2_pt"]
        plt.hist(np.log(frame[f]).replace([np.inf,-np.inf],np.nan).dropna(),bins=200,density=True,histtype='step')
    plt.title(f)
    plt.show()
# Out:
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ...

# %%
from sklearn.utils import shuffle
from sklearn import model_selection , preprocessing
from sklearn.model_selection import train_test_split

# %% [markdown]
# function to get training and testing data, it also plots all the pretty scatter plots if you ask nicely

# %%
def getXYdata(newfeatures,plot=False):
    MEGADATA = shuffle(pd.concat(frames,ignore_index=True)).reset_index(drop=True)
    x1 = MEGADATA.loc[MEGADATA['isSignal']==1]
    x2 = MEGADATA.loc[MEGADATA['isSignal']==0].sample(n=x1.shape[0])
    assert x1.size == x2.size
    MEGADATA = shuffle(pd.concat([x1,x2]))
    X = MEGADATA[features[:-1]]
    Y = MEGADATA['isSignal']

    assert X.shape[0] == Y.shape[0]
    if plot:
        for f in newfeatures:
            for f1 in newfeatures:
                if f!=f1:
                    plt.scatter(MEGADATA[f].loc[MEGADATA['isSignal']==1],MEGADATA[f1].loc[MEGADATA['isSignal']==1],label='signal',s=0.1,alpha=0.1)
                    plt.scatter(MEGADATA[f].loc[MEGADATA['isSignal']==0],MEGADATA[f1].loc[MEGADATA['isSignal']==0],label='background',s=0.1,alpha=0.1)
                    plt.legend()
                    plt.title("{} vs {}".format(f,f1))
                    plt.show()

    sc = preprocessing.StandardScaler ()
    X_train,X_test,Y_train,Y_test = train_test_split(sc.fit_transform(X[newfeatures]),Y,train_size=0.7,random_state=69,shuffle=True)

    assert X_train.shape[1] == X_test.shape[1] 
    
    return (X_train,X_test,Y_train,Y_test)

# %%
newfeatures = ["lep2_pt","lep1_pt","fatjet_pt","fatjet_eta","fatjet_D2","Zll_mass","Zll_pt","MET"]
newfeatures1 = ["lep2_pt","lep1_pt","fatjet_pt","fatjet_eta","fatjet_D2","Zll_mass","Zll_pt","MET","reco_zv_mass"]

# %%
# X = X[newfeatures]
# MEGADATA['isSignal']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow . keras . layers import Dropout
def my_model( num_inputs , num_nodes , extra_depth ):
    # create model
    model = Sequential()
    model.add( Dense( num_nodes , input_dim = num_inputs , kernel_initializer ="normal", \
    activation ="relu"))
    model.add( Dropout(0.2))
    for i in range ( extra_depth ):
        # code up the extra layers here
        model.add( Dense(num_nodes, activation ="relu"))
#         model.add(Dropout(0.2))
        # Compile model
    model.add(Dense(1,activation="sigmoid"))
    model.compile( loss ="binary_crossentropy", optimizer ="adam", metrics =["accuracy"])
    return model

# %%
X_train, X_test, Y_train, Y_test = getXYdata(newfeatures,plot=True)

# %%
net = my_model(8,20,1)
history = net.fit(X_train,Y_train,batch_size=512,epochs=50,validation_data=(X_test,Y_test))
# Out:
# Train on 70018 samples, validate on 30008 samples
# Epoch 1/50
# 70018/70018 [==============================] - 3s 45us/sample - loss: 0.5056 - accuracy: 0.8090 - val_loss: 0.3362 - val_accuracy: 0.8720
# Epoch 2/50
# 70018/70018 [==============================] - 4s 56us/sample - loss: 0.3173 - accuracy: 0.8772 - val_loss: 0.2958 - val_accuracy: 0.8842
# Epoch 3/50
# 70018/70018 [==============================] - 2s 23us/sample - loss: 0.3012 - accuracy: 0.8822 - val_loss: 0.2902 - val_accuracy: 0.8861
# Epoch 4/50
# 70018/70018 [==============================] - 3s 40us/sample - loss: 0.2950 - accuracy: 0.8838 - val_loss: 0.2865 - val_accuracy: 0.8876
# Epoch 5/50
# 70018/70018 [==============================] - 3s 46us/sample - loss: 0.2920 - accuracy: 0.8846 - val_loss: 0.2845 - val_accuracy: 0.8874
# Epoch 6/50
# 70018/70018 [==============================] - 2s 26us/sample - loss: 0.2899 - accuracy: 0.8861 - val_loss: 0.2822 - val_accuracy: 0.8880
# Epoch 7/50
# ...

# %%
plotModel(history,net)
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.958

# %%
from  tensorflow.keras import optimizers
from tensorflow.keras.layers import BatchNormalization

def my_better_model( num_inputs , num_nodes , extra_depth ):
    # create model
    model = Sequential()
    model.add( Dense( num_nodes , input_dim = num_inputs , kernel_initializer ="normal", \
    activation ="relu"))
    model.add( Dropout(0.2))
    for i in range ( extra_depth ):
        # code up the extra layers here
        n=max(128,1024-(4*i)**2)
        print(n)
        model.add( Dense(n , activation ="relu"))
#         if i % 2:
        model.add(BatchNormalization(axis=-1, momentum=0.9, epsilon=0.001, center=True, scale=True))
#         else:
        model.add(Dropout(0.1))


        # Compile model
    model.add(Dense(1,activation="sigmoid"))
    o = optimizers.Adam(learning_rate=0.001)

    model.compile( loss ="binary_crossentropy", optimizer =o , metrics =["accuracy"])
    return model

# %%
def my_better_better_model( num_inputs , num_nodes , extra_depth ):
    # create model
    model = Sequential()
    model.add( Dense( num_nodes , input_dim = num_inputs , kernel_initializer ="normal", \
    activation ="relu"))
    model.add( Dropout(0.2))
    model.add( Dense(32, activation ="relu"))
    model.add(BatchNormalization(axis=-1, momentum=0.9, epsilon=0.001, center=True, scale=True))
    model.add( Dense(64, activation ="relu"))
    model.add(BatchNormalization(axis=-1, momentum=0.9, epsilon=0.001, center=True, scale=True))
    model.add( Dense(64, activation ="relu"))
    model.add(BatchNormalization(axis=-1, momentum=0.9, epsilon=0.001, center=True, scale=True))
    model.add( Dense(64, activation ="relu"))
    model.add( Dense(64, activation ="relu"))
    model.add( Dense(32, activation ="relu"))

#     for i in range ( extra_depth ):
#         # code up the extra layers here
#         n=512#max(128,1024-(4*i)**2)
#         print(n)
#         model.add( Dense(n , activation ="relu"))
#         if i % 2 == 0:
#             model.add(Dropout(0.05))
#         else:
#             model.add(BatchNormalization(axis=-1, momentum=0.9, epsilon=0.001, center=True, scale=True))

        # Compile model
#     model.add(Dense(128,activation="sigmoid"))

    model.add(Dense(1,activation="sigmoid"))
    o = optimizers.Adam(learning_rate=0.001)

    model.compile( loss ="binary_crossentropy", optimizer =o , metrics =["accuracy"])
    return model

# %%
def plotModel(history,net):
    Y_pr = net.predict(X_test)
    predicts = (Y_pr>0.5).astype(int)
    ns_probs = [0 for _ in range(len(Y_test))]
    lr_probs = Y_pr#torch.cat(outs).numpy()[:,1]

    # keep probabilities for the positive outcome only
    # lr_probs = lr_probs[:, 1]
    # calculate scores
    ns_auc = roc_auc_score(Y_test, ns_probs)
    lr_auc = roc_auc_score(Y_test, lr_probs)
    # summarize scores
    print('No Skill: ROC AUC=%.3f' % (ns_auc))
    print('Logistic: ROC AUC=%.3f' % (lr_auc))
    # calculate roc curves
    ns_fpr, ns_tpr, _ = roc_curve(Y_test, ns_probs)
    lr_fpr, lr_tpr, _ = roc_curve(Y_test, lr_probs)
    # plot the roc curve for the model
    plt.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
    plt.plot(lr_fpr, lr_tpr, marker='.', label='NN')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    # show the legend
    plt.legend()
    # show the plot
    plt.show()
    
    cm = confusion_matrix(predicts.reshape(-1,1),Y_test.to_numpy())
    normcm = np.flip(cm/np.sum(cm,axis=1),axis=0)
    sn.heatmap(normcm,annot=True,cmap='Blues',xticklabels=["0","1"],yticklabels=["1","0"])
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title("loss")
    plt.xlabel("epoch")
    plt.ylabel("Binary Cross Entropy Loss")
    plt.show()
    plt.plot(history.history['accuracy'])
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.show()

# %%
X_train, X_test, Y_train, Y_test = getXYdata(newfeatures1,plot=False)

# %%
net = my_better_model(9,32,4)
history = net.fit(X_train,Y_train,batch_size=512,epochs=50,validation_data=(X_test,Y_test))
plotModel(history,net)

# %%
from keras.callbacks import EarlyStopping , ModelCheckpoint
callbacks_ = [
# if we don ’t have an increase of the accuracy for 10 epochs , terminate training .
EarlyStopping ( verbose = True , patience =10 , monitor ="val_acc") ,
# Always make sure that we ’re saving the model weights with the best accuracy .
ModelCheckpoint ("model.h5", monitor ="val_acc", verbose =0 , save_best_only = True , mode ="max")]
# history = net.fit(X_train,Y_train,batch_size=512,epochs=50,validation_data=(X_test,Y_test),callbacks = callbacks_,verbose=True )
# Out:
# Using TensorFlow backend.

# %%
losses = []
ax = plt.axes()
ax1 = plt.axes()
for i in range(5):
    net = my_better_model(9,20,i)
    history = net.fit(X_train,Y_train,batch_size=512,epochs=10,validation_data=(X_test,Y_test),callbacks = callbacks_,verbose=True )
    losses.append(history.history['loss'][-1])
    ax.plot(history.history['loss'],label = "loss - {}".format(i))
    ax1.plot(history.history['val_accuracy'],label="accuracy- {}".format(i))
# Out:
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Train on 70018 samples, validate on 30008 samples
# Epoch 1/10
# 70018/70018 [==============================] - 3s 36us/sample - loss: 0.4963 - accuracy: 0.8384 - val_loss: 0.3622 - val_accuracy: 0.8791
# Epoch 2/10
# 17920/70018 [======>.......................] - ETA: 0s - loss: 0.3586 - accuracy: 0.8759
# ...

# %%
n = np.argmin(losses)
print(n)
# Out:
# 4

# %%
net = my_better_model(9,20,4)
history = net.fit(X_train,Y_train,batch_size=512,epochs=50,validation_data=(X_test,Y_test),callbacks = callbacks_,verbose=True )
plotModel(history,net)
# Out:
# 1024
# 1008
# 960
# 880
# Train on 70018 samples, validate on 30008 samples
# Epoch 1/50
# 70018/70018 [==============================] - 15s 214us/sample - loss: 0.2732 - accuracy: 0.9042 - val_loss: 0.1877 - val_accuracy: 0.9312
# Epoch 2/50
#  1024/70018 [..............................] - ETA: 12s - loss: 0.2318 - accuracy: 0.9131
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# ...

# %%
net = my_better_better_model(9,20,n)
history = net.fit(X_train,Y_train,batch_size=512,epochs=50,validation_data=(X_test,Y_test),callbacks = callbacks_,verbose=True )
plotModel(history,net)
# Out:
# Train on 70018 samples, validate on 30008 samples
# Epoch 1/50
# 70018/70018 [==============================] - 6s 86us/sample - loss: 0.2635 - accuracy: 0.8992 - val_loss: 0.1838 - val_accuracy: 0.9351
# Epoch 2/50
#  2560/70018 [>.............................] - ETA: 4s - loss: 0.1982 - accuracy: 0.9270
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /home/lewis/.conda/envs/AIenv/lib/python3.7/site-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 70018/70018 [==============================] - 4s 59us/sample - loss: 0.1911 - accuracy: 0.9305 - val_loss: 0.1780 - val_accuracy: 0.9367
# Epoch 3/50
# ...

# %%
net = my_better_better_model(9,20,n)
history = net.fit(X_train,Y_train,batch_size=512,epochs=50,validation_data=(X_test,Y_test),callbacks = callbacks_,verbose=True )
plotModel(history,net
# Out:
#   File "<ipython-input-41-75095da83557>", line 3
#     plotModel(history,net
#                          ^
# SyntaxError: unexpected EOF while parsing
